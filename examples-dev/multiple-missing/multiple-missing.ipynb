# %%
# !af3io data-fill --help
# Out:
# Usage: af3io data-fill [OPTIONS]
#
#   Read an input JSON, fill in data pipeline strings from matching sequences
#   found in files under --data_dir. Files produced under --output_dir can then
#   be used as input for AlphaFold 3 inference, skipping the data pipeline step.
#
#   Files under --data_dir can be either plain JSON (_data.json) or compressed
#   with gzip (_data.json.gz). Can specify --data_dir multiple times.
#
#   Data pipeline output is matched by sequence, there is no need to keep a
#   consistent set of sequence identifiers (across projects/people/labs) and/or
#   file names while still sharing data pipeline output.
#
#   For more than a handful of files in --data_dir, use --write-index to pre-
#   compute a sequence-JSON lookup table. This avoids excessive I/O from
#   repeatedly reading every file under --data_dir. The index is stored in
#   .af3io_data_index.json under --data_dir as a plain-text JSON.
#
# ...

# %%
# !af3io data-fill --data_dir data_atox1 --data_dir data_pool
# Out:
# Create data index from: data_atox1
# Reading files:  [####################################]  100%
# Read 1 protein sequence(s)
# Create data index from: data_pool
# Reading files:  [####################################]  100%
# Read 18 protein sequence(s)
# Data index has 19 protein, 0 dna, 0 rna sequence(s)

# %%
# !af3io data-fill --data_dir data_atox1
# Out:
# Create data index from: data_atox1
# Reading files:  [####################################]  100%
# Read 1 protein sequence(s)
# Data index has 1 protein, 0 dna, 0 rna sequence(s)

# %%
# !af3io data-fill --data_dir data_pool
# Out:
# Create data index from: data_pool
# Reading files:  [####################################]  100%
# Read 18 protein sequence(s)
# Data index has 18 protein, 0 dna, 0 rna sequence(s)

# %%
# !af3io data-fill --data_dir data_atox1 --write-index
# Out:
# Create data index from: data_atox1
# Reading files:  [####################################]  100%
# Read 1 protein sequence(s)
# Writing index to: data_atox1/.af3io_data_index.json
# Data index has 1 protein, 0 dna, 0 rna sequence(s)

# %%
# !af3io data-fill --data_dir data_atox1 --data_dir data_pool
# Out:
# Load data index from: data_atox1/.af3io_data_index.json
# Read 1 protein sequence(s)
# Create data index from: data_pool
# Reading files:  [####################################]  100%
# Read 18 protein sequence(s)
# Data index has 19 protein, 0 dna, 0 rna sequence(s)

# %%
# !af3io data-fill --data_dir data_atox1 --data_dir data_pool --input_dir input_test --missing_dir missing_test
# Out:
# Load data index from: data_atox1/.af3io_data_index.json
# Read 1 protein sequence(s)
# Create data index from: data_pool
# Reading files:  [####################################]  100%
# Read 18 protein sequence(s)
# Data index has 19 protein, 0 dna, 0 rna sequence(s)
# Read:	input_test/missing_test.json
# Write:	missing_test/missing_test_b.json
# Write:	missing_test/missing_test_c.json
# Write:	missing_test/missing_test_d.json

# %%
# !af3io data-fill --data_dir data_atox1 --data_dir data_pool --input_dir input_test --missing_dir missing_test --output_dir output_test
# Out:
# Traceback (most recent call last):
#   File "/cluster/project/beltrao/jjaenes/26.01_batch-infer/.venv/bin/af3io", line 7, in <module>
#     sys.exit(cli())
#              ~~~^^
#   File "/cluster/project/beltrao/jjaenes/26.01_batch-infer/.venv/lib/python3.13/site-packages/click/core.py", line 1485, in __call__
#     return self.main(*args, **kwargs)
#            ~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/cluster/project/beltrao/jjaenes/26.01_batch-infer/.venv/lib/python3.13/site-packages/click/core.py", line 1406, in main
#     rv = self.invoke(ctx)
#   File "/cluster/project/beltrao/jjaenes/26.01_batch-infer/.venv/lib/python3.13/site-packages/click/core.py", line 1873, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^
#   File "/cluster/project/beltrao/jjaenes/26.01_batch-infer/.venv/lib/python3.13/site-packages/click/core.py", line 1269, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
# ...

# %%
# !rm -rf data_atox1/.af3io_data_index.json
# !rm -rf data_pool/.af3io_data_index.json
# !rm -rf missing_test/
