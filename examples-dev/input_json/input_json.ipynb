# %%
import os.path
from af3_io import input_json, datafill

# %%
input_json.init()

# %%
js = input_json.from_sequences('QOWIUR', 'QWRIOU')
js

# %%
input_json.pprint(js)

# %%
path = os.path.expanduser('~/batch-infer/results/alphafold3_adhoc_examples/alphafold3_msas/atox1_data.json.gz')
input_json.pprint(input_json.read(path))
