# %%
#!rm -rf decompress-unzip atox1.af3io.zip
#!cp -R $PROJECT/25.06.03_batch-infer/results/alphafold3_adhoc_examples/alphafold3_predictions/atox1 .
#!gunzip -r atox1

# %%
# !af3io compress atox1/ atox1.af3io.zip
#!unzip atox1.af3io.zip -d decompress-unzip

# %%
# !af3io decompress-test atox1.af3io.zip ./

# %%
#!diff -r -q atox1/ decompress/atox1/

# %%
#!rm -rf atox1/ decompress/atox1 atox1.af3io.zip
#!rm -rf decompress/atox1
