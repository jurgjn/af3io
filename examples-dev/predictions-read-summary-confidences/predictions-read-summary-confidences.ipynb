# %%
from pathlib import Path
import af3io

# %%
# v3.0.1
path = '/cluster/project/beltrao/jjaenes/26.01_batch-infer/pooled-ppi-yeast/predictions/26.01-euler-std-a100-r3/alphafold3_predictions/00119555583d674eeda18bde21ca4b557eddd410.zip'
af3io.predictions.read_summary_confidences(path)
# Out:
#                                        name  seed  sample  ranking_score  \
# 0  00119555583d674eeda18bde21ca4b557eddd410     4       0       0.354730
# 1  00119555583d674eeda18bde21ca4b557eddd410     4       1       0.341501
# 2  00119555583d674eeda18bde21ca4b557eddd410     4       2       0.361526
# 3  00119555583d674eeda18bde21ca4b557eddd410     4       3       0.348847
# 4  00119555583d674eeda18bde21ca4b557eddd410     4       4       0.342822
#
#    fraction_disordered  has_clash  iptm   ptm  \
# 0                 0.10        0.0  0.28  0.39
# 1                 0.07        0.0  0.29  0.39
# 2                 0.12        0.0  0.28  0.39
# 3                 0.09        0.0  0.28  0.38
# 4                 0.08        0.0  0.28  0.39
#
#                                           chain_iptm  \
# 0  [0.11, 0.07, 0.08, 0.09, 0.06, 0.08, 0.08, 0.1...
# 1  [0.11, 0.07, 0.08, 0.09, 0.06, 0.08, 0.08, 0.1...
# 2  [0.11, 0.07, 0.08, 0.09, 0.06, 0.07, 0.08, 0.1...
# ...

# %%
# b78e215
path = '/cluster/project/beltrao/jjaenes/26.01_batch-infer/pooled-ppi-yeast/predictions/26.01-euler-std-a100-r3-b78e215/alphafold3_predictions/011d701e24b1de59ed14e14ad37e01197eb68e00.zip'
af3io.predictions.read_summary_confidences(path)
# Out:
#                                        name  seed  sample  ranking_score  \
# 0  011d701e24b1de59ed14e14ad37e01197eb68e00     4       0       0.352743
# 1  011d701e24b1de59ed14e14ad37e01197eb68e00     4       1       0.359034
# 2  011d701e24b1de59ed14e14ad37e01197eb68e00     4       2       0.347979
# 3  011d701e24b1de59ed14e14ad37e01197eb68e00     4       3       0.350513
# 4  011d701e24b1de59ed14e14ad37e01197eb68e00     4       4       0.340038
#
#    fraction_disordered  has_clash  iptm   ptm  \
# 0                 0.11        0.0  0.29  0.35
# 1                 0.12        0.0  0.28  0.35
# 2                 0.10        0.0  0.28  0.35
# 3                 0.10        0.0  0.29  0.35
# 4                 0.09        0.0  0.28  0.35
#
#                                           chain_iptm  \
# 0  [0.12, 0.09, 0.09, 0.07, 0.09, 0.08, 0.08, 0.0...
# 1  [0.12, 0.09, 0.09, 0.07, 0.09, 0.08, 0.08, 0.0...
# 2  [0.12, 0.09, 0.09, 0.07, 0.08, 0.08, 0.08, 0.0...
# ...
